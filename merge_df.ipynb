# %%
import pandas as pd

# %%
df_2011_2019 = pd.read_csv('data/players_list_2011~2019.csv')
df_2011_2019
# Out:
#    kor_name            eng_name     team  release      end_dt
# 0   더스틴 니퍼트      dustin nippert       두산        0  2010-12-31
# 1    크리스 세든        chris seddon       sk        0  2011-12-31
# 2   다나 이브랜드  dana james eveland       한화        0  2011-12-31
# 3     헨리 소사          henry sosa       기아        0  2011-12-31
# 4     아담 윌크    adam robert wilk       NC        0  2011-12-31
# ..      ...                 ...      ...      ...         ...
# 68  라울 알칸타라      raul alcantara       두산        0  2018-12-31
# 69  저스틴 헤일리        justin haley  시즌 중 방출        1  2018-12-31
# 70   워윅 서폴드     warwick saupold       한화        0  2018-12-31
# 71  드류 루친스키       drew rucinski       NC        0  2018-12-31
# 72   제이크 톰슨       jake thompson  시즌 중 방출        1  2018-12-31
#
# [73 rows x 5 columns]

# %%
df_2020_2022 = pd.read_csv('data/players_list.csv')
df_2020_2022
# Out:
#        kor_name               eng_name team  release      end_dt
# 0       크리스 플렉센           chris flexen   두산        0  2019-12-31
# 1          닉 킹엄           nick kingham   sk        1  2019-12-31
# 2       리카르도 핀토  ricardo antonio pinto   sk        0  2019-12-31
# 3       마이크 라이트            mike wright   nc        0  2019-12-31
# 4   오드리사머 데스파이네    odrisamer despaigne   kt        0  2019-12-31
# 5        애런 브룩스       aaron lee brooks   기아        0  2019-12-31
# 6         드류 가뇽            drew gagnon   기아        0  2019-12-31
# 7      데이비드 뷰캐넌         david buchanan   삼성        0  2019-12-31
# 8       댄 스트레일리            dan straily   롯데        0  2019-12-31
# 9       아드리안 샘슨   adrian david sampson   롯데        0  2019-12-31
# 10       웨스 파슨스            wes parsons   nc        0  2020-12-31
# 11      아리엘 미란다          ariel miranda   두산        0  2020-12-31
# 12        워커 로켓         walker lockett   두산        0  2020-12-31
# ...

# %%
df = pd.concat([df_2011_2019,df_2020_2022]).reset_index(drop=True)
df
# Out:
#      kor_name               eng_name team  release      end_dt
# 0     더스틴 니퍼트         dustin nippert   두산        0  2010-12-31
# 1      크리스 세든           chris seddon   sk        0  2011-12-31
# 2     다나 이브랜드     dana james eveland   한화        0  2011-12-31
# 3       헨리 소사             henry sosa   기아        0  2011-12-31
# 4       아담 윌크       adam robert wilk   NC        0  2011-12-31
# ..        ...                    ...  ...      ...         ...
# 103     찰리 반즈         charlie barnes   롯데        0  2021-12-31
# 104      션 놀린             sean nolin   기아        0  2021-12-31
# 105   로니 윌리엄스  ronnie ellis williams   기아        1  2021-12-31
# 106    펠릭스 페냐     felix ricardo pena   한화        0  2021-12-31
# 107  예프리 라미레즈          yefry ramirez   한화        0  2021-12-31
#
# [108 rows x 5 columns]

# %%
df.to_csv('2011_2022_players_list.csv',index=False)
