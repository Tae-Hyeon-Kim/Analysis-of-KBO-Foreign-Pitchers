# %%
import pandas as pd
import numpy as np
import pybaseball

# %% [markdown]
# # Data Load

# %%
players_lst = pd.read_csv('data/2011_2022_players_list.csv')
players_lst
# Out:
#      kor_name               eng_name team  release      end_dt
# 0     더스틴 니퍼트         dustin nippert   두산        0  2010-12-31
# 1      크리스 세든           chris seddon   sk        0  2011-12-31
# 2     다나 이브랜드     dana james eveland   한화        0  2011-12-31
# 3       헨리 소사             henry sosa   기아        0  2011-12-31
# 4       아담 윌크       adam robert wilk   NC        0  2011-12-31
# ..        ...                    ...  ...      ...         ...
# 103     찰리 반즈         charlie barnes   롯데        0  2021-12-31
# 104      션 놀린             sean nolin   기아        0  2021-12-31
# 105   로니 윌리엄스  ronnie ellis williams   기아        1  2021-12-31
# 106    펠릭스 페냐     felix ricardo pena   한화        0  2021-12-31
# 107  예프리 라미레즈          yefry ramirez   한화        0  2021-12-31
#
# [108 rows x 5 columns]

# %% [markdown]
# # id를 추출하기 위한 전처리

# %% [markdown]
# ## pybaseball 라이브러리에 검색이 되지 않는 선수 확인

# %%
tmp_lst = []
for tmp in players_lst['eng_name']:
    if len(pybaseball.playerid_lookup(tmp.split(' ')[-1],tmp.split(' ')[0]))!=1:
        tmp_lst.append(tmp)
        print(tmp,':',len(pybaseball.playerid_lookup(tmp.split(' ')[-1],tmp.split(' ')[0])))
# Out:
# jo : 0
# rick vandenhurk : 0
# sugar ray marimon : 0
# hector noesi : 0
# carl allen webster : 0
# james seth frankoff : 0
# scott logan verrett : 0
# william deck mcguire : 0
# raul alcantara : 0
# ariel miranda : 0
# josh smith : 3
# albert joe suarez : 0
# tyler eppler : 0
# ivan manuel nova : 0
# ronnie ellis williams : 0
# felix ricardo pena : 0
# yefry ramirez : 0

# %% [markdown]
# ## 올바른 이름 찾아서 최신화

# %%
for i in range(len(tmp_lst)):    
    print(players_lst.loc[players_lst['eng_name']==tmp_lst[i]]['kor_name'].values[0])
# Out:
# 조조 레이예스
# 릭 밴덴헐크
# 슈가 레이 마리몬
# 헥터 노에시
# 앨런 웹스터
# 세스 후랭코프
# 로건 베렛
# 덱 맥과이어
# 라울 알칸타라
# 아리엘 미란다
# 조쉬 스미스
# 알버트 수아레즈
# 타일러 애플러
# 이반 노바
# 로니 윌리엄스
# 펠릭스 페냐
# 예프리 라미레즈

# %% [markdown]
# ### jo-jo

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[0]]
# Out:
#   kor_name eng_name team  release      end_dt
# 6  조조 레이예스       jo   sk        0  2012-12-31

# %%
pybaseball.playerid_lookup('reyes','jo-jo')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     reyes      jo-jo     457456  reyej003  reyesjo03           5559
#
#    mlb_played_first  mlb_played_last
# 0            2007.0           2016.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[0],'eng_name'] = 'jo-jo reyes'
players_lst.loc[players_lst['eng_name']=='jo-jo reyes']
# Out:
#   kor_name     eng_name team  release      end_dt
# 6  조조 레이예스  jo-jo reyes   sk        0  2012-12-31

# %% [markdown]
# ### 릭 벤덴헐크

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[1]]
# Out:
#   kor_name         eng_name team  release      end_dt
# 9   릭 밴덴헐크  rick vandenhurk   삼성        0  2012-12-31

# %%
pybaseball.playerid_lookup('van den hurk','rick')
# Out:
#       name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0  van den hurk       rick     462995  vandr001  vanderi01           5099
#
#    mlb_played_first  mlb_played_last
# 0            2007.0           2012.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[1],'eng_name'] = 'rick,van den hurk'
players_lst.loc[players_lst['eng_name']=='rick,van den hurk']
# Out:
#   kor_name           eng_name team  release      end_dt
# 9   릭 밴덴헐크  rick,van den hurk   삼성        0  2012-12-31

# %% [markdown]
# ### 마리몬
# - statcast data를 추출하는 과정에서 오류를 발견
# - end_dt 2014->2015로 변경

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[2]]
# Out:
#      kor_name           eng_name     team  release      end_dt
# 30  슈가 레이 마리몬  sugar ray marimon  시즌 중 방출        1  2014-12-31

# %%
pybaseball.playerid_lookup('marimon')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   marimon  sugar ray     516970  maris001  marimsu01           6027
#
#    mlb_played_first  mlb_played_last
# 0            2015.0           2015.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[2],'eng_name'] = 'sugar ray,marimon'
players_lst.loc[players_lst['eng_name']=='sugar ray,marimon','end_dt'] = '2015-12-31'

# %% [markdown]
# ### 헥터

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[3]]
# Out:
#    kor_name      eng_name team  release      end_dt
# 34   헥터 노에시  hector noesi   기아        0  2015-12-31

# %%
pybaseball.playerid_lookup('noesí')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     noesí     hector     456051  noesh001  noesihe01           3292
#
#    mlb_played_first  mlb_played_last
# 0            2011.0           2019.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[3],'eng_name'] = 'hector noesí'

# %% [markdown]
# ### 웹스터

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[4]]
# Out:
#    kor_name            eng_name     team  release      end_dt
# 43   앨런 웹스터  carl allen webster  시즌 중 방출        1  2015-12-31

# %%
pybaseball.playerid_lookup('webster','allen')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   webster      allen     543903  websa001  webstal01           3993
#
#    mlb_played_first  mlb_played_last
# 0            2013.0           2019.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[4],'eng_name'] = 'allen webster'
players_lst.loc[players_lst['eng_name']=='allen webster']
# Out:
#    kor_name       eng_name     team  release      end_dt
# 43   앨런 웹스터  allen webster  시즌 중 방출        1  2015-12-31

# %% [markdown]
# ### 후랭코프

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[5]]
# Out:
#    kor_name             eng_name team  release      end_dt
# 52  세스 후랭코프  james seth frankoff   두산        0  2016-12-31

# %%
pybaseball.playerid_lookup('frankoff','seth')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0  frankoff       seth     571676  frans001  frankse01          11346
#
#    mlb_played_first  mlb_played_last
# 0            2017.0           2021.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[5],'eng_name'] = 'seth frankoff'

# %% [markdown]
# ### 베렛

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[6]]
# Out:
#    kor_name             eng_name team  release      end_dt
# 56    로건 베렛  scott logan verrett   NC        0  2017-12-31

# %%
pybaseball.playerid_lookup('verrett','logan')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   verrett      logan     548337  verrl001  verrelo01          12905
#
#    mlb_played_first  mlb_played_last
# 0            2015.0           2017.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[6],'eng_name'] = 'logan verrett'

# %% [markdown]
# ### 맥과이어

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[7]]
# Out:
#    kor_name              eng_name     team  release      end_dt
# 67   덱 맥과이어  william deck mcguire  시즌 중 방출        1  2018-12-31

# %%
pybaseball.playerid_lookup('mcguire','deck')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   mcguire       deck     592547  mcgud001  mcguide02          11596
#
#    mlb_played_first  mlb_played_last
# 0            2017.0           2018.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[7],'eng_name'] = 'deck mcguire'

# %% [markdown]
# ### 알칸타라

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[8]]
# Out:
#    kor_name        eng_name team  release      end_dt
# 68  라울 알칸타라  raul alcantara   두산        0  2018-12-31

# %%
pybaseball.playerid_lookup('Alcántara','Raúl')
# Out:
#    name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0  alcántara       raúl     593417  alcar001  alcanra01          12790
#
#    mlb_played_first  mlb_played_last
# 0            2016.0           2017.0

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[8],'eng_name'] = 'Raúl Alcántara'

# %% [markdown]
# ### 미란다

# %%
# 아리엘 미란다
tmp = pybaseball.playerid_lookup(tmp_lst[9].split(' ')[-1])
players_lst.loc[players_lst['eng_name']==tmp_lst[9],'eng_name'] = tmp.loc[3,'name_first'] +' '+ tmp.loc[3,'name_last']
tmp
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   miranda      willy     119184  miraw101  miranwi01        1008991
# 1   miranda       jose     669304  miraj002  miranjo01          20538
# 2   miranda       juan     506673  miraj001  miranju01           7783
# 3   miranda      aríel     664641  miraa002  miranar01          17526
# 4   miranda      angel     119183  miraa001  miranan01        1008990
#
#    mlb_played_first  mlb_played_last
# 0            1951.0           1959.0
# 1            2022.0           2023.0
# 2            2008.0           2011.0
# 3            2016.0           2018.0
# 4            1993.0           1997.0

# %% [markdown]
# ### 조쉬 스미스

# %%
# 조쉬 스미스
tmp = pybaseball.playerid_lookup(tmp_lst[10].split(' ')[-1],tmp_lst[10].split(' ')[0])
tmp
# index 2
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     smith       josh     605479  smitj006  smithjo08          13629
# 1     smith       josh     669701  smitj007  smithjo11          26396
# 2     smith       josh     595001  smitj004  smithjo07          10946
#
#    mlb_played_first  mlb_played_last
# 0            2019.0           2020.0
# 1            2022.0           2023.0
# 2            2015.0           2020.0

# %% [markdown]
# ### 수아레즈

# %%
players_lst.loc[players_lst['eng_name']==tmp_lst[11]]
# Out:
#     kor_name           eng_name team  release      end_dt
# 96  알버트 수아레즈  albert joe suarez   삼성        0  2021-12-31

# %%
# 알버트 수아레즈
tmp = pybaseball.playerid_lookup('Suárez')
players_lst.loc[players_lst['eng_name']==tmp_lst[11],'eng_name'] = tmp.loc[0,'name_first'] +' '+ tmp.loc[0,'name_last']
tmp
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0    suárez     albert     544150  suara001  suareal01           6175
# 1    suárez     ranger     624133  suarr001  suarera01          17277
# 2    suárez    eugenio     553993  suare001  suareeu01          12552
# 3    suárez     andrew     605498  suara002  suarean01          18300
# 4    suárez       josé         -1       NaN  suarejo02             -1
#
#    mlb_played_first  mlb_played_last
# 0            2016.0           2017.0
# 1            2018.0           2023.0
# 2            2014.0           2023.0
# 3            2018.0           2023.0
# 4            1921.0           1921.0

# %% [markdown]
# ### 애플러

# %%
# 타일러 애플러
tmp = pybaseball.playerid_lookup(tmp_lst[3].split(' ')[-1])
tmp
# mlb 경력 없음
# Out:
# Empty DataFrame
# Columns: [name_last, name_first, key_mlbam, key_retro, key_bbref, key_fangraphs, mlb_played_first, mlb_played_last]
# Index: []

# %% [markdown]
# ### 이반 노바

# %%
# 이반 노바
tmp = pybaseball.playerid_lookup(tmp_lst[13].split(' ')[-1])
players_lst.loc[players_lst['eng_name']==tmp_lst[13],'eng_name'] = tmp.loc[0,'name_first'] +' '+ tmp.loc[0,'name_last']
tmp
# Out:
#   name_last name_first  key_mlbam key_retro key_bbref  key_fangraphs  \
# 0      nova       iván     467100  novai001  novaiv01           1994
#
#    mlb_played_first  mlb_played_last
# 0            2010.0           2020.0

# %% [markdown]
# ### 윌리엄스

# %%
# 로니 윌리엄스
tmp = pybaseball.playerid_lookup(tmp_lst[5].split(' ')[-1],tmp_lst[5].split(' ')[0])
tmp
# mlb 경력 없음
# Out:
# Empty DataFrame
# Columns: [name_last, name_first, key_mlbam, key_retro, key_bbref, key_fangraphs, mlb_played_first, mlb_played_last]
# Index: []

# %% [markdown]
# ### 페냐

# %%
# 펠릭스 페냐
tmp = pybaseball.playerid_lookup('Peña','Félix')
players_lst.loc[players_lst['eng_name']==tmp_lst[15],'eng_name'] = 'Félix Peña'
tmp
# Out:
#   name_last name_first  key_mlbam key_retro key_bbref  key_fangraphs  \
# 0      peña      félix     570240  penaf002  penafe01          13403
#
#    mlb_played_first  mlb_played_last
# 0            2016.0           2021.0

# %% [markdown]
# ### 예프리 라미레즈

# %%
# 예프리 라미레즈
tmp = pybaseball.playerid_lookup('Ramírez')
players_lst.loc[players_lst['eng_name']==tmp_lst[16],'eng_name'] = tmp.loc[4,'name_first'] +' '+ tmp.loc[4,'name_last']
tmp
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   ramírez     ramiro         -1       NaN  ramirra04             -1
# 1   ramírez       josé     542432  ramij004  ramirjo02          10171
# 2   ramírez       roel     641995  ramir005  ramirro02          16470
# 3   ramírez     erasmo     541640  ramie004  ramirer02          10314
# 4   ramírez      yefry     606162  ramiy001  ramirye01          15655
# 5   ramírez     alexei     493351  ramia003  ramiral03           5133
# 6   ramírez     harold     623912  ramih004  ramirha02          14387
# 7   ramírez      j. c.     500724  ramij002  ramirjc01           8302
# 8   ramírez       neil     519166  ramin001  ramirne01           7677
# 9   ramírez       josé     608070  ramij003  ramirjo01          13510
#
#    mlb_played_first  mlb_played_last
# 0            1923.0           1932.0
# 1            2014.0           2018.0
# 2            2020.0           2021.0
# 3            2012.0           2023.0
# ...

# %%
players_lst
# Out:
#      kor_name               eng_name team  release      end_dt
# 0     더스틴 니퍼트         dustin nippert   두산        0  2010-12-31
# 1      크리스 세든           chris seddon   sk        0  2011-12-31
# 2     다나 이브랜드     dana james eveland   한화        0  2011-12-31
# 3       헨리 소사             henry sosa   기아        0  2011-12-31
# 4       아담 윌크       adam robert wilk   NC        0  2011-12-31
# ..        ...                    ...  ...      ...         ...
# 103     찰리 반즈         charlie barnes   롯데        0  2021-12-31
# 104      션 놀린             sean nolin   기아        0  2021-12-31
# 105   로니 윌리엄스  ronnie ellis williams   기아        1  2021-12-31
# 106    펠릭스 페냐             Félix Peña   한화        0  2021-12-31
# 107  예프리 라미레즈          yefry ramírez   한화        0  2021-12-31
#
# [108 rows x 5 columns]

# %%
for tmp in players_lst['eng_name']:
    if len(pybaseball.playerid_lookup(tmp.split(' ')[-1],tmp.split(' ')[0]))!=1:
        print(tmp,':',len(pybaseball.playerid_lookup(tmp.split(' ')[-1],tmp.split(' ')[0])))
# Out:
# rick,van den hurk : 0
# sugar ray,marimon : 0
# josh smith : 3
# tyler eppler : 0
# ronnie ellis williams : 0

# %% [markdown]
# # id 추출

# %%
def get_name_first_last(x):
    if ',' in x:
        name_first,name_last = x.split(',')[-1], x.split(',')[0]
    else:
        name_first,name_last = x.split(' ')[-1], x.split(' ')[0]
    return name_first, name_last

# %%
def get_start_dt(x):
    name_first, name_last = get_name_first_last(x)
    tmp = pybaseball.playerid_lookup(name_first,name_last)
    return str(int(tmp.iloc[-1]['mlb_played_first']))+'-01-01' if len(tmp)>0 else np.nan

def get_savant_id(x):
    name_first, name_last = get_name_first_last(x)
    tmp = pybaseball.playerid_lookup(name_first,name_last)
    return tmp.iloc[-1]['key_mlbam'] if len(tmp)>0 else np.nan

def get_fangraphs_id(x):
    name_first, name_last = get_name_first_last(x)
    tmp = pybaseball.playerid_lookup(name_first,name_last)
    return tmp.iloc[-1]['key_fangraphs'] if len(tmp)>0 else np.nan

def get_player_id(x):
    name_first, name_last = get_name_first_last(x)
    tmp = pybaseball.playerid_lookup(name_first,name_last)
    return tmp.iloc[-1]['key_bbref'] if len(tmp)>0 else np.nan

players_lst['start_dt'] = players_lst['eng_name'].apply(get_start_dt)
players_lst['savant_id'] = players_lst['eng_name'].apply(get_savant_id)
players_lst['fangraphs_id'] = players_lst['eng_name'].apply(get_fangraphs_id)
players_lst['player_id'] = players_lst['eng_name'].apply(get_player_id)

players_lst
# Out:
#      kor_name               eng_name team  release      end_dt    start_dt  \
# 0     더스틴 니퍼트         dustin nippert   두산        0  2010-12-31  2005-01-01
# 1      크리스 세든           chris seddon   sk        0  2011-12-31  2007-01-01
# 2     다나 이브랜드     dana james eveland   한화        0  2011-12-31  2005-01-01
# 3       헨리 소사             henry sosa   기아        0  2011-12-31  2011-01-01
# 4       아담 윌크       adam robert wilk   NC        0  2011-12-31  2011-01-01
# ..        ...                    ...  ...      ...         ...         ...
# 103     찰리 반즈         charlie barnes   롯데        0  2021-12-31  2021-01-01
# 104      션 놀린             sean nolin   기아        0  2021-12-31  2013-01-01
# 105   로니 윌리엄스  ronnie ellis williams   기아        1  2021-12-31         NaN
# 106    펠릭스 페냐             Félix Peña   한화        0  2021-12-31  2016-01-01
# 107  예프리 라미레즈          yefry ramírez   한화        0  2021-12-31  2018-01-01
#
#      savant_id  fangraphs_id  player_id
# ...

# %%
# mlb 경력없는 선수 삭제
players_lst = players_lst[~players_lst['savant_id'].isna()].reset_index(drop=True)
players_lst
# Out:
#      kor_name            eng_name team  release      end_dt    start_dt  \
# 0     더스틴 니퍼트      dustin nippert   두산        0  2010-12-31  2005-01-01
# 1      크리스 세든        chris seddon   sk        0  2011-12-31  2007-01-01
# 2     다나 이브랜드  dana james eveland   한화        0  2011-12-31  2005-01-01
# 3       헨리 소사          henry sosa   기아        0  2011-12-31  2011-01-01
# 4       아담 윌크    adam robert wilk   NC        0  2011-12-31  2011-01-01
# ..        ...                 ...  ...      ...         ...         ...
# 101   글렌 스파크맨      glenn sparkman   롯데        0  2021-12-31  2017-01-01
# 102     찰리 반즈      charlie barnes   롯데        0  2021-12-31  2021-01-01
# 103      션 놀린          sean nolin   기아        0  2021-12-31  2013-01-01
# 104    펠릭스 페냐          Félix Peña   한화        0  2021-12-31  2016-01-01
# 105  예프리 라미레즈       yefry ramírez   한화        0  2021-12-31  2018-01-01
#
#      savant_id  fangraphs_id  player_id
# 0     430962.0        4426.0  nippedu01
# ...

# %% [markdown]
# # statcast data 추출

# %%
pybaseball.statcast_pitcher(players_lst.loc[0,'start_dt'],players_lst.loc[0,'end_dt'],players_lst.loc[0,'savant_id'])
# Out:
# Gathering Player Data
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2010-10-09           93.0          -1.88           6.90
# 1            FF  2010-10-09           95.2          -1.88           6.89
# 2            FF  2010-10-09           94.3          -1.87           7.01
# 3            FF  2010-10-09           94.0          -1.77           6.91
# 4            FF  2010-10-09           92.8          -1.74           6.88
# ...         ...         ...            ...            ...            ...
# 5518        NaN  2005-09-08            NaN            NaN            NaN
# 5519        NaN  2005-09-08            NaN            NaN            NaN
# 5520        NaN  2005-09-08            NaN            NaN            NaN
# 5521        NaN  2005-09-08            NaN            NaN            NaN
# 5522        NaN  2005-09-08            NaN            NaN            NaN
#
# ...

# %% [markdown]
# ## 오류 수정

# %% [markdown]
# - 팻 딘, 후랭코프, 휠러 end_dt 수정

# %%
players_lst.loc[players_lst['eng_name']=='pat dean','end_dt'] = '2016-12-31'

# %%
players_lst.loc[players_lst['eng_name']=='seth frankoff','end_dt'] = '2017-12-31'
players_lst.loc[players_lst['eng_name']=='jason wheeler','end_dt'] = '2017-12-31'

# %%
for i in range(len(players_lst)):
    end = int(players_lst.loc[i,'end_dt'].split('-')[0])
    start = int(players_lst.loc[i,'start_dt'].split('-')[0])
    if end < start:
        print(players_lst.loc[i,'kor_name'])

# %%
players_lst.iloc[40:76]
# Out:
#       kor_name                eng_name     team  release      end_dt  \
# 40         팻 딘                pat dean       기아        0  2016-12-31
# 41    스캇 다이아몬드   scott michael diamond       sk        0  2015-12-31
# 42     지크 스프루일            zeke spruill       기아        0  2015-12-31
# 43      앨런 웹스터           allen webster  시즌 중 방출        1  2015-12-31
# 44     스캇 코프랜드    scott reast copeland       엘지        0  2015-12-31
# 45       제프 맨쉽            jeff manship       NC        0  2016-12-31
# 46  카를로스 비야누에바       carlos villanueva       한화        0  2016-12-31
# 47    펠릭스 듀브론트  felix antonio doubront  시즌 중 방출        1  2016-12-31
# 48     알렉시 오간도            alexi ogando       한화        0  2016-12-31
# 49     에스밀 로저스    esmil antonio rogers       넥센        0  2016-12-31
# 50     제이크 브리검            jake brigham       키움        0  2016-12-31
# 51       팀 아델만             tim adleman       삼성        0  2016-12-31
# 52     세스 후랭코프           seth frankoff       두산        0  2016-12-31
# ...

# %%
# pd.concat([pybaseball.statcast_pitcher(players_lst.loc[1,'start_dt'],players_lst.loc[1,'end_dt'],players_lst.loc[1,'savant_id']),
#            pybaseball.statcast_pitcher(players_lst.loc[0,'start_dt'],players_lst.loc[0,'end_dt'],players_lst.loc[0,'savant_id'])])

# %%
df = pd.DataFrame()
for i in range(len(players_lst)):
    tmp = players_lst.loc[i]
    print(tmp['kor_name'])
    tmp_df = pybaseball.statcast_pitcher(tmp['start_dt'],tmp['end_dt'],tmp['savant_id'])
    print('완료')
    df = pd.concat([df,tmp_df])
# Out:
# 더스틴 니퍼트
# Gathering Player Data
# 완료
# 크리스 세든
# Gathering Player Data
# 완료
# 다나 이브랜드
# Gathering Player Data
# 완료
# 헨리 소사
# Gathering Player Data
# 완료
# 아담 윌크
# Gathering Player Data
# 완료
# 하이로 어센시오
# Gathering Player Data
# 완료
# 조조 레이예스
# Gathering Player Data
# 완료
# 개릿 올슨
# Gathering Player Data
# 완료
# 에릭 해커
# Gathering Player Data
# 완료
# 릭 밴덴헐크
# Gathering Player Data
# 완료
# 태드 웨버
# Gathering Player Data
# 완료
# 로스 울프
# Gathering Player Data
# 완료
# 루카스 하렐
# Gathering Player Data
# 완료
# 알프레도 피가로
# Gathering Player Data
# 완료
# 앤드류 앨버스
# Gathering Player Data
# 완료
# 미치 탈보트
# Gathering Player Data
# 완료
# 라이언 피어밴드
# Gathering Player Data
# 완료
# 조쉬 린드블럼
# Gathering Player Data
# 완료
# 크리스 볼스테드
# Gathering Player Data
# 완료
# 필립 험버
# Gathering Player Data
# 완료
# 저스틴 토마스
# Gathering Player Data
# 완료
# 유네스키 마야
# Gathering Player Data
# 완료
# 에버렛 티포드
# Gathering Player Data
# 완료
# 필 어윈
# Gathering Player Data
# 완료
# 로버트 코엘로
# Gathering Player Data
# 완료
# 에반 믹
# Gathering Player Data
# 완료
# ...

# %%
# df = pd.concat([pybaseball.statcast_pitcher(players_lst.loc[i,'start_dt']
#                                        ,players_lst.loc[i,'end_dt'],
#                                        players_lst.loc[i,'savant_id']) for i in range(len(players_lst))])

# %%
df
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2010-10-09           93.0          -1.88           6.90
# 1            FF  2010-10-09           95.2          -1.88           6.89
# 2            FF  2010-10-09           94.3          -1.87           7.01
# 3            FF  2010-10-09           94.0          -1.77           6.91
# 4            FF  2010-10-09           92.8          -1.74           6.88
# ...         ...         ...            ...            ...            ...
# 1853        NaN  2018-02-28            NaN            NaN            NaN
# 1854        NaN  2018-02-28            NaN            NaN            NaN
# 1855        NaN  2018-02-28            NaN            NaN            NaN
# 1856        NaN  2018-02-28            NaN            NaN            NaN
# 1857        NaN  2018-02-28            NaN            NaN            NaN
#
#           player_name  batter pitcher     events    description  ...  \
# ...

# %%
import pickle
with open("savant_final_df.pkl","wb") as fw:
    pickle.dump(df, fw)
